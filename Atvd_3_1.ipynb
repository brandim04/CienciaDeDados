# %% [markdown]
# <a href="https://colab.research.google.com/github/brandim04/CienciaDeDados/blob/main/Atvd_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
from sklearn.impute import KNNImputer

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("yasserh/housing-prices-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'housing-prices-dataset' dataset.
# Path to dataset files: /kaggle/input/housing-prices-dataset

# %%
df = pd.read_csv(f'{path}/Housing.csv')

# %%
print(df.head())
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100
missing_df = pd.DataFrame({
    'Valores Ausentes': missing_values,
    'Porcentagem (%)': missing_percentage
})

print(missing_df[missing_df['Valores Ausentes'] > 0])
# Out:
# Empty DataFrame
# Columns: [Valores Ausentes, Porcentagem (%)]
# Index: []

# %% [markdown]
# Não há valores ausentes
